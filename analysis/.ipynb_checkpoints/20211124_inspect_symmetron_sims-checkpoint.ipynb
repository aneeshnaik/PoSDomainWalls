# %%
import numpy as np
import matplotlib.pyplot as plt
kpc = 3.0857e+19
year = 31557600.0
Gyr = 1e+9 * year

# %%
data = np.load("../symmetron/unscreened_v400_a8.npz")

t = data['times'] / Gyr
v = data['v']
z = data['z'] / kpc
acc = data['acc']

# %%
plt.plot(t, v / v[-1])
plt.ylim(0.99, 1.01);

# %%
plt.plot(t, acc)

# %%
plt.plot(t, z)

# %%
plt.plot(t, v/v[-1])
plt.ylim(0.99, 1.01)
# Out:
# (0.99, 1.01)

# %%
v[0]/v[-1]
# Out:
# 1.0000304786947702
